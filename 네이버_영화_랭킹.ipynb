# %% [markdown]
# <a href="https://colab.research.google.com/github/murur/pythonbasic-1month-/blob/main/%EB%84%A4%EC%9D%B4%EB%B2%84_%EC%98%81%ED%99%94_%EB%9E%AD%ED%82%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 크롤링 과제 https://movie.naver.com/movie/sdb/rank/rmovie.naver

import requests                       # 웹페이지 연결
from bs4 import BeautifulSoup as bs   # 가져온 페이지를 분석하기 용이하게 정제
import pandas as pd                   # 데이터 분석 도구

html = requests.get('https://movie.naver.com/movie/sdb/rank/rmovie.naver')
soup = bs(html.text)
print(soup)

# %%
len(soup.select('tr > td.title'))
# Out:
# 50

# %%
movies = soup.select('tr > td.title')
movie = movies[0]
movie
# Out:
# <td class="title">
# <div class="tit3">
# <a href="/movie/bi/mi/basic.naver?code=182016" title="닥터 스트레인지: 대혼돈의 멀티버스">닥터 스트레인지: 대혼돈의 멀티버스</a>
# </div>
# </td>

# %%
soup.select('td.title')
# Out:
# [<td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=182016" title="닥터 스트레인지: 대혼돈의 멀티버스">닥터 스트레인지: 대혼돈의 멀티버스</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=164122" title="신비한 동물들과 덤블도어의 비밀">신비한 동물들과 덤블도어의 비밀</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=196362" title="공기살인">공기살인</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=159812" title="니 부모 얼굴이 보고 싶다">니 부모 얼굴이 보고 싶다</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=192608" title="범죄도시2">범죄도시2</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=190374" title="앵커">앵커</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=201795" title="영희">영희</a>
#  </div>
# ...

# %%
movies = soup.select('tr > td.title')
len(movies[0].select('div.tit3 > a'))
# Out:
# 1

# %%
movies[0].select('div.tit3 > a')
# Out:
# [<a href="/movie/bi/mi/basic.naver?code=182016" title="닥터 스트레인지: 대혼돈의 멀티버스">닥터 스트레인지: 대혼돈의 멀티버스</a>]

# %%
movies[0].select('div.tit3 > a')[0].text
# Out:
# '닥터 스트레인지: 대혼돈의 멀티버스'

# %%
movie_data = []
rank = 1

movies = soup.select('tr > td.title')

for movie in movies:
  title = movie.select('div.tit3 > a')[0].text
  movie_data.append(['Movie',rank,title])
  rank += 1

movie_data
# Out:
# [['Movie', 1, '닥터 스트레인지: 대혼돈의 멀티버스'],
#  ['Movie', 2, '신비한 동물들과 덤블도어의 비밀'],
#  ['Movie', 3, '공기살인'],
#  ['Movie', 4, '니 부모 얼굴이 보고 싶다'],
#  ['Movie', 5, '범죄도시2'],
#  ['Movie', 6, '앵커'],
#  ['Movie', 7, '영희'],
#  ['Movie', 8, '부기나이트'],
#  ['Movie', 9, '로스트 시티'],
#  ['Movie', 10, '배드 가이즈'],
#  ['Movie', 11, '스텔라'],
#  ['Movie', 12, '불도저에 탄 소녀'],
#  ['Movie', 13, '수퍼 소닉2'],
#  ['Movie', 14, '서울괴담'],
#  ['Movie', 15, '봄날'],
#  ['Movie', 16, '더 컨트랙터'],
#  ['Movie', 17, '언차티드'],
#  ['Movie', 18, '뜨거운 피'],
#  ['Movie', 19, '엄마'],
#  ['Movie', 20, '극장판 귀멸의 칼날: 무한열차편'],
#  ['Movie', 21, '극장판 주술회전 0'],
#  ['Movie', 22, '쥬라기 월드: 도미니언'],
#  ['Movie', 23, '앰뷸런스'],
#  ['Movie', 24, '더 배트맨'],
#  ['Movie', 25, '스파이더맨: 노 웨이 홈'],
#  ['Movie', 26, '우연과 상상'],
#  ['Movie', 27, '한산: 용의 출현'],
#  ['Movie', 28, '브로커'],
#  ['Movie', 29, '세븐틴 파워 오브 러브 : 더 무비'],
#  ['Movie', 30, '중경삼림'],
#  ['Movie', 31, '민스미트 작전'],
#  ['Movie', 32, '이상한 나라의 수학자'],
#  ['Movie', 33, '마녀(魔女) Part2. The Other One'],
# ...

# %%
df = pd.DataFrame(movie_data, columns = ['영화','순위','제목'])
df
# Out:
#        영화  순위                           제목
# 0   Movie   1          닥터 스트레인지: 대혼돈의 멀티버스
# 1   Movie   2            신비한 동물들과 덤블도어의 비밀
# 2   Movie   3                         공기살인
# 3   Movie   4               니 부모 얼굴이 보고 싶다
# 4   Movie   5                        범죄도시2
# 5   Movie   6                           앵커
# 6   Movie   7                           영희
# 7   Movie   8                        부기나이트
# 8   Movie   9                       로스트 시티
# 9   Movie  10                       배드 가이즈
# 10  Movie  11                          스텔라
# 11  Movie  12                    불도저에 탄 소녀
# 12  Movie  13                       수퍼 소닉2
# 13  Movie  14                         서울괴담
# 14  Movie  15                           봄날
# 15  Movie  16                       더 컨트랙터
# 16  Movie  17                         언차티드
# 17  Movie  18                        뜨거운 피
# 18  Movie  19                           엄마
# 19  Movie  20            극장판 귀멸의 칼날: 무한열차편
# 20  Movie  21                   극장판 주술회전 0
# ...

# %%
df.to_excel('movie.xlsx', index=False)
